# %%
from network import Net
from trainers import *
from utils import *
import numpy as np
import pandas as pd

# %%
file_path = '..\datasets\monk_dataset\monks-1.train'
data = pd.read_csv(file_path, delimiter=' ', header=None, skipinitialspace=True)
data = np.array(data)
n, m = data.shape

#splitting the data in X and Y
x_train = data[:, 1:m-1]
y_train = data[:, 0]

x_train = one_hot_monk(x_train)

file_path = file_path = '..\datasets\monk_dataset\monks-1.test'
data = pd.read_csv(file_path, delimiter=' ', header=None, skipinitialspace=True)
data = np.array(data)
n, m = data.shape # r, c

x_test = data[:, 1:m-1]
y_test = data[:, 0]

x_test = one_hot_monk(x_test)

network = Net('./config_monk.yaml')
network.print_structure()

results = train_and_evaluate(x_train, y_train, x_test, y_test, network.get_W(), network.get_b(), network.get_layers(), network.get_hyperparameters())

# print the results of the dict in a readable way but Model
for key in results.keys():
    if key != 'model':
        print(key, ' : ', results[key])
# Out:
# Layer 1: Units = 4, Activation = relu
# Layer 2: Units = 1, Activation = sigmoid
# train_loss  :  0.0006301161754227276
# test_loss  :  0.002337201029817045
# train_metric  :  100.0
# test_metric  :  100.0

# %%
file_path = '..\datasets\monk_dataset\monks-2.train'
data = pd.read_csv(file_path, delimiter=' ', header=None, skipinitialspace=True)
data = np.array(data)
n, m = data.shape

#splitting the data in X and Y
x_train = data[:, 1:m-1]
y_train = data[:, 0]

x_train = one_hot_monk(x_train)

file_path = file_path = '..\datasets\monk_dataset\monks-2.test'
data = pd.read_csv(file_path, delimiter=' ', header=None, skipinitialspace=True)
data = np.array(data)
n, m = data.shape # r, c

x_test = data[:, 1:m-1]
y_test = data[:, 0]

x_test = one_hot_monk(x_test)

network = Net('./config_monk.yaml')
network.print_structure()

results = train_and_evaluate(x_train, y_train, x_test, y_test, network.get_W(), network.get_b(), network.get_layers(), network.get_hyperparameters())

# print the results of the dict in a readable way but Model
for key in results.keys():
    if key != 'model':
        print(key, ' : ', results[key])
# Out:
# Layer 1: Units = 4, Activation = relu
# Layer 2: Units = 1, Activation = sigmoid
# train_loss  :  0.0003474591893140984
# test_loss  :  0.00037718696763660155
# train_metric  :  100.0
# test_metric  :  100.0

# %%
file_path = '..\datasets\monk_dataset\monks-3.train'
data = pd.read_csv(file_path, delimiter=' ', header=None, skipinitialspace=True)
data = np.array(data)
n, m = data.shape

#splitting the data in X and Y
x_train = data[:, 1:m-1]
y_train = data[:, 0]

x_train = one_hot_monk(x_train)

file_path = file_path = '..\datasets\monk_dataset\monks-3.test'
data = pd.read_csv(file_path, delimiter=' ', header=None, skipinitialspace=True)
data = np.array(data)
n, m = data.shape # r, c

x_test = data[:, 1:m-1]
y_test = data[:, 0]

x_test = one_hot_monk(x_test)

network = Net('./config_monk.yaml')
network.print_structure()

results = train_and_evaluate(x_train, y_train, x_test, y_test, network.get_W(), network.get_b(), network.get_layers(), network.get_hyperparameters())

# print the results of the dict in a readable way but Model
for key in results.keys():
    if key != 'model':
        print(key, ' : ', results[key])
# Out:
# Layer 1: Units = 4, Activation = relu
# Layer 2: Units = 1, Activation = sigmoid
# train_loss  :  0.0018660998312700345
# test_loss  :  0.0661183459556815
# train_metric  :  100.0
# test_metric  :  92.36111111111111

# %%
file_path = '..\datasets\monk_dataset\monks-3.train'
data = pd.read_csv(file_path, delimiter=' ', header=None, skipinitialspace=True)
data = np.array(data)
n, m = data.shape

#splitting the data in X and Y
x_train = data[:, 1:m-1]
y_train = data[:, 0]

x_train = one_hot_monk(x_train)

file_path = file_path = '..\datasets\monk_dataset\monks-3.test'
data = pd.read_csv(file_path, delimiter=' ', header=None, skipinitialspace=True)
data = np.array(data)
n, m = data.shape # r, c

x_test = data[:, 1:m-1]
y_test = data[:, 0]

x_test = one_hot_monk(x_test)

network = Net('./config_monk.yaml')
network.print_structure()

results = train_and_evaluate(x_train, y_train, x_test, y_test, network.get_W(), network.get_b(), network.get_layers(), network.get_hyperparameters())

# print the results of the dict in a readable way but Model
for key in results.keys():
    if key != 'model':
        print(key, ' : ', results[key])
# Out:
# Layer 1: Units = 4, Activation = relu
# Layer 2: Units = 1, Activation = sigmoid
# train_loss  :  0.04904108562098423
# test_loss  :  0.036438274349688
# train_metric  :  93.44262295081968
# test_metric  :  97.22222222222221
